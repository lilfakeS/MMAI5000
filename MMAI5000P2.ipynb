# %%
import requests
from bs4 import BeautifulSoup
import datetime

# %%
url_withoutday = 'https://dd.weather.gc.ca/alerts/cap/'
current_date = datetime.datetime.now()
formatted_date = current_date.strftime("%Y%m%d")
url = url_withoutday + formatted_date + '/'
reqs = requests.get(url)
soup = BeautifulSoup(reqs.text,'html.parser')

urls = []
for link in soup.find_all('a'):
    print(link.get('herf'))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
import xml.etree.ElementTree as ET 
import pandas as pd

# %%
tree = ET. parse ('/Users/justinsheng/Downloads/T_WSCN11_C_CWHX_202308090110_3302326297.cap') 
root = tree. getroot() 
print (root.tag) 
#for child in root: 
# #print (child.tag, child.text) 
data = [] 
xmlns = root.tag.strip('alert') 

for alert_info in root.findall (xmlns+'info'): 
    for area in alert_info.findall(xmlns+'area'):
    #print(area. find(xmlnst'areaDesc') .text) 
        alert_dict = { 
            'sender' :
            alert_info.find(xmlns+'senderName').text, 
            'language' :
            alert_info.find(xmlns+'language'). text, 
            'area' :
            area.find(xmlns+ 'areaDesc').text, 
            'headline' :
            alert_info.find(xmlns+'headline'). text, 
            'category': 
            alert_info.find(xmlns+'category').text, 
            'event': 
            alert_info.find(xmlns+'event' ).text, 
            'response_type' : 
            alert_info.find(xmlns+'responseType') .text, 
            'urgency' :
            alert_info.find(xmlns+ 'urgency').text, 
            'severity': 
            alert_info.find(xmlns+'severity').text, 
            'certainty' :
            alert_info.find(xmlns+ 'certainty').text, 
            'audience': 
            alert_info.find(xmlns+'audience').text, 
            'effective': 
            alert_info.find(xmlns+'effective'). text, 
            'expires': 
            alert_info.find(xmlns+'expires').text, 
            } 
        
data.append (alert_dict) 
print (pd.DataFrame (data))
data
# Out:
# {urn:oasis:names:tc:emergency:cap:1.2}alert
#                  sender language                                    area
# 0  Environnement Canada    fr-CA  ville de Sydney et comté de Cap-Breton  \
#
#                                      headline category  event response_type
# 0  bulletin météorologique spécial en vigueur      Met  météo       Monitor  \
#
#   urgency severity certainty      audience                  effective
# 0  Future    Minor  Possible  grand public  2023-08-09T01:15:58-00:00  \
#
#                      expires
# 0  2023-08-09T17:10:26-00:00
# [{'sender': 'Environnement Canada',
#   'language': 'fr-CA',
#   'area': 'ville de Sydney et comté de Cap-Breton',
#   'headline': 'bulletin météorologique spécial en vigueur',
#   'category': 'Met',
#   'event': 'météo',
#   'response_type': 'Monitor',
#   'urgency': 'Future',
#   'severity': 'Minor',
#   'certainty': 'Possible',
#   'audience': 'grand public',
#   'effective': '2023-08-09T01:15:58-00:00',
#   'expires': '2023-08-09T17:10:26-00:00'}]

# %%
data = [] 
alert_info = root.find('{urn:oasis: names: tc :emergency: cap:1.2}info') 

for area in alert_info.findall(xmlns+'area'):
    alert_dict = {'sender': alert_info.find(xmlns+'senderName'). text, 
                  #'language' :alert_info.find(xmlns+ 'language').text, 
                  'area': area.find(xmlns+'areaDesc').text, 
                  'headline': alert_info.find(xmlns+ 'headline').text, 
                  'category': alert_info.find(xmlns+'category').text, 
                  'event': alert_info.find(xmlns+'event') .text, 
                  'response_type': alert_info.find(xmlns+'responseType').text, 
                  'urgency': alert_info.find(xmlns+'urgency').text, 
                  'severity': alert_info.find(xmlns+'severity').text,
                  'certainty': alert_info.find(xmlns+'certainty').text, 
                  'audience': alert_info.find(xmlns+'audience').text,
                  'effective': alert_info.find(xmlns+'effective').text, 
                  'expires': alert_info.find(xmlns+'expires').text, }
                  
data.append(alert_dict) 

print (pd. DataFrame (data)) 
for parameter in alert_info.findall(xmlns+'parameter'): 
  if "Alert_Type" in parameter. find(xmlns+'valueName').text: 
    print (parameter.find(xmlns+'value') .text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 4
#       1 data = []
#       2 alert_info = root.find('{urn:oasis: names: tc :emergency: cap:1.2}info')
# ----> 4 for area in alert_info.findall(xmlns+'area'):
#       5     alert_dict = {'sender': alert_info.find(xmlns+'senderName'). text,
#       6                   #'language' :alert_info.find(xmlns+ 'language').text,
#       7                   'area': area.find(xmlns+'areaDesc').text,
#    (...)
#      16                   'effective': alert_info.find(xmlns+'effective').text,
#      17                   'expires': alert_info.find(xmlns+'expires').text, }
#      19 data.append(alert_dict)
#
# AttributeError: 'NoneType' object has no attribute 'findall'
